# %%
import yfinance as yf
from datetime import date
import pandas as pd

# %%
data = yf.download("AAPL", start="2024-01-01", end="2024-02-20")
df = pd.read

# %%
import matplotlib.pyplot as plt

data1 = yf.download("AAPL", start="2020-01-01", end="2021-01-01")
data2 = yf.download("AAPL", start="2021-01-01", end="2022-01-04")
data3 = yf.download("AAPL", start="2022-01-01", end="2023-01-05")
data4 = yf.download("AAPL", start="2023-01-01", end="2024-01-05")
data2.index = data1.index
data3.index = data1.index
data4.index = data1.index
plt.figure()
plt.plot(data1['Close'])
plt.plot(data2['Close'])
plt.plot(data3['Close'])
plt.plot(data4['Close'])
plt.title("Apple Stock Prices")
plt.legend(['2020','2021','2022','2023'])
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
multi_data = yf.download(["AAPL", "MSFT"], start="2020-01-01", end="2021-01-01")
multi_data.anext() head()
pd.
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price       Adj Close                  Close                   High  \
# Ticker           AAPL        MSFT       AAPL        MSFT       AAPL
# Date
# 2020-01-02  73.059410  154.493835  75.087502  160.619995  75.150002
# 2020-01-03  72.349136  152.570099  74.357498  158.619995  75.144997
# 2020-01-06  72.925629  152.964508  74.949997  159.029999  74.989998
# 2020-01-07  72.582672  151.569778  74.597504  157.580002  75.224998
# 2020-01-08  73.750244  153.984039  75.797501  160.089996  76.110001
#
# Price                         Low                   Open              \
# Ticker            MSFT       AAPL        MSFT       AAPL        MSFT
# Date
# 2020-01-02  160.729996  73.797501  158.330002  74.059998  158.779999
# 2020-01-03  159.949997  74.125000  158.059998  74.287498  158.320007
# 2020-01-06  159.100006  73.187500  156.509995  73.447502  157.080002
# ...

# %%
type(multi_data)
# Out:
# pandas.core.frame.DataFrame

# %%
>>> multicol1 = pd.MultiIndex.from_tuples([('weight', 'kg'),
...                                        ('weight', 'pounds')])
>>> df_multi_level_cols1 = pd.DataFrame([[1, 2], [2, 4]],
...                                     index=['cat', 'dog'],
...                                     columns=multicol1)
